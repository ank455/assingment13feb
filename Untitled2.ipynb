# %%
# Ans 1

Custom exceptions provide you the flexibility to add attributes and methods that are not part of a standard Java exception.

# %%
# Ans 2
import inspect 
print("The class hierarchy for built in exception is :")
inspect.getclasstree(inspect.getmro(Exception))
def classtree(cls, indent = 0):
    print('.' * indent,cls.__name__)
    for subcls in cls .__subclasses__():
        classtree(subcls , indent + 3 )
classtree(Exception)
# Out:
# The class hierarchy for built in exception is :
#  Exception
# ... TypeError
# ...... FloatOperation
# ...... MultipartConversionError
# ... StopAsyncIteration
# ... StopIteration
# ... ImportError
# ...... ModuleNotFoundError
# ...... ZipImportError
# ... OSError
# ...... ConnectionError
# ......... BrokenPipeError
# ......... ConnectionAbortedError
# ......... ConnectionRefusedError
# ......... ConnectionResetError
# ............ RemoteDisconnected
# ...... BlockingIOError
# ...... ChildProcessError
# ...... FileExistsError
# ...... FileNotFoundError
# ...... IsADirectoryError
# ...... NotADirectoryError
# ...... InterruptedError
# ......... InterruptedSystemCall
# ...... PermissionError
# ...... ProcessLookupError
# ...... TimeoutError
# ...... UnsupportedOperation
# ...... itimer_error
# ...... herror
# ...... gaierror
# ...... SSLError
# ......... SSLCertVerificationError
# ......... SSLZeroReturnError
# ......... SSLWantWriteError
# ......... SSLWantReadError
# ...

# %%
# Ans 3

Error's defined in arithmeticerror are :
Zero division error
Over flow error 
Floating point error

# %%
# Example of Zerodivisionerror
import logging
logging.basicConfig(filename = "kumar.log" , level = logging.ERROR)
try:
    10/0
except ZeroDivisionError as e:
    logging.error("i am trying to handle a zerodivisioerror{}" .format(e))

# %%
# Example of overflow error
1.2-1.0
# Out:
# 0.19999999999999996

# %%
# Ans4
The LookupError exception in Python forms the base class for all exceptions that are raised when an index or a key is not found for a sequence or dictionary respectively.

# %%
# Key error 
try :
    a = {"key" :"ankit" , 1:[1,2,3,]}
    print(a["key3"])
except KeyError as e:
    print(e)
# Out:
# 'key3'

# %%
# IndexError 
try :
    a = [1,2,3,4,1,651,1,1]
    print(a[8])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %%
# Ans 5
This error occur when we use module that cannot be found.

Module not found error is a syntax error that appears when the static import the statement cannot find the file at declared path.

# %%
# Ans 6
best exception for practice are 
1) keyerror
2) indexerror
3)moduleerror
4)filenotfounderror
